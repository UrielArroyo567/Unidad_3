# %% [markdown]
# <a href="https://colab.research.google.com/github/UrielArroyo567/Unidad_3/blob/main/Practica4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

lambda_poisson = 5
n = 100

U = np.random.uniform(0, 1, n)

def poisson_inverse_transform(lambda_poisson, u):
    k = 0
    F_k = math.exp(-lambda_poisson)
    while u > F_k:
        k += 1
        F_k += (lambda_poisson**k * math.exp(-lambda_poisson)) / math.factorial(k)
    return k

poisson_vectorizado = np.vectorize(poisson_inverse_transform)
demanda_simulada = poisson_vectorizado(lambda_poisson, U)

print("Demanda diaria simulada:", demanda_simulada)

plt.hist(demanda_simulada, bins=np.arange(0, max(demanda_simulada) + 2) - 0.5,
         edgecolor='black', density=True)
plt.title("Simulación de demanda diaria (Distribución Poisson)")
plt.xlabel("Número de productos demandados")
plt.ylabel("Frecuencia")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Demanda diaria simulada: [ 7  6  6  3  7  6  4 10  5  6  2  6  7  4  8  2  7  2  5  4  4  7  6  5
#   5  5  8  6  1  4  5  3  4  8  3  1  2  4  1  5  5  3  8  5  2  7  3  4
#   4  7  7  3  2  8 10  5  3  4  5  2  4  3  7  5  3  5  8  6  2  4  6  5
#   3  3  6  5  7  4  7  4  6  1  6  5  8  7  2  4  3  1  4  4  8  6  4  5
#   6  5  4  4]
